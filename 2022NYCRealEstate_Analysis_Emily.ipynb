# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
# import Sales Price (Brooklyn, Manhattan, Queens)
houseprice_df = pd.read_csv('priceIndex_All.csv')
houseprice_df
houseprice_df['year'] = pd.DatetimeIndex(houseprice_df['Month']).year
houseprice_df_year = houseprice_df[['year']]

# %%
rentprice_df = pd.read_csv('rentalIndex_All.csv')

# %%
#house sell prices before, during and after covid
covidh_df = houseprice_df.loc[(houseprice_df['Month'] >= '2019-12-01')]

# %%
rentprice_df = pd.read_csv('rentalIndex_All.csv')
rentprice_df['year'] = pd.DatetimeIndex(rentprice_df['Month']).year
rentprice_df_year = rentprice_df[['year']]
rentprice_df.tail(5)
# Out:
#           Month  Brooklyn  Manhattan     NYC  Queens  year
# 181  2022-02-01    2834.0     3396.0  3019.0  2222.0  2022
# 182  2022-03-01    2872.0     3461.0  3067.0  2237.0  2022
# 183  2022-04-01    2917.0     3527.0  3121.0  2257.0  2022
# 184  2022-05-01    2963.0     3599.0  3182.0  2292.0  2022
# 185  2022-06-01    3022.0     3660.0  3242.0  2330.0  2022

# %%
#plot rent and sell home prices from 2007-2021

houseprice_df = houseprice_df.loc[(houseprice_df['Month'] >= '2007-01-01')]
plt.rcParams['figure.figsize']=(10,6)
houseprice_df.plot(x='Month',y=['Manhattan','Brooklyn','Queens'],label = ['Manhattan','Brooklyn','Queens'])
plt.xlabel('Month') 
#plt.xticks(rotation='vertical')
plt.ylabel('Price')
plt.title('Selling Price', fontsize = 20)

plt.rcParams['figure.figsize']=(10,6)
rentprice_df.plot(x='Month',y=['Manhattan','Brooklyn','Queens'],label = ['Manhattan','Brooklyn','Queens'])
plt.xlabel('Month') 
plt.xticks(rotation='horizontal')
plt.ylabel('Price')
plt.title('Rent', fontsize = 20)
#rentprice_df
# Out:
# Text(0.5, 1.0, 'Rent')

# %%
covidr_df = rentprice_df.loc[(rentprice_df['Month'] >= '2019-12-01')]
covidh_df2020 = covidh_df.loc[(covidh_df['Month'] <= '2021-03-01')]
covidh_df2020
# Out:
#           Month  Brooklyn  Manhattan     NYC  Queens  year
# 179  2019-12-01    696920    1089182  620568  507661  2019
# 180  2020-01-01    704329    1089413  623906  512027  2020
# 181  2020-02-01    705245    1082625  620005  509534  2020
# 182  2020-03-01    703102    1078313  622136  514979  2020
# 183  2020-04-01    698044    1081661  618399  511626  2020
# 184  2020-05-01    689321    1078894  610782  505967  2020
# 185  2020-06-01    691415    1070363  611055  508343  2020
# 186  2020-07-01    693839    1068078  608704  504464  2020
# 187  2020-08-01    684877    1059208  606611  501074  2020
# 188  2020-09-01    681482    1053692  606774  503421  2020
# 189  2020-10-01    682329    1048923  605328  503080  2020
# 190  2020-11-01    679080    1036411  604685  504676  2020
# 191  2020-12-01    670942    1028495  602884  508512  2020
# 192  2021-01-01    668913    1025270  604053  508254  2021
# 193  2021-02-01    660655    1022852  599897  506337  2021
# 194  2021-03-01    655943    1018325  594468  501881  2021

# %%
plt.rcParams['figure.figsize']=(10,6)
covidh_df2020.plot(x='Month',y=['Manhattan','Brooklyn','Queens'],label = ['Manhattan','Brooklyn','Queens'])
plt.xlabel('Month') 
plt.xticks(rotation='horizontal')
plt.ylabel('Price')
plt.title('Rent', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Rent')

# %%
#price comparison between sell house and rent house - before and post pandemic (2019-2022)
plt.rcParams['figure.figsize']=(5,4)
covidr_df.plot(x='Month',y=['Manhattan','Brooklyn','Queens'],label = ['Manhattan','Brooklyn','Queens'])
plt.xlabel('Month') 
plt.xticks(rotation='vertical')
plt.ylabel('Price')
plt.title('Rent', fontsize = 20)

plt.rcParams['figure.figsize']=(5,4)
covidh_df.plot(x='Month',y=['Manhattan','Brooklyn','Queens'],label = ['Manhattan','Brooklyn','Queens'])
plt.xlabel('Month') 
plt.xticks(rotation='vertical')
plt.ylabel('Price')
plt.title('Sell', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Sell')

# %%
#sell price pct change between lowest and highest - the sharp raise
postcovidh_df = covidh_df.loc[covidh_df['Month'].isin(['2021-03-01', '2022-06-01'])]
postcovidh_pct=postcovidh_df[['Manhattan','Brooklyn','Queens']].pct_change()

postcovidh_pct
# Out:
#      Manhattan  Brooklyn    Queens
# 194        NaN       NaN       NaN
# 209   0.082569  0.052148  0.036937

# %%
#rent price pct change between lowest and highest - the sharp raise
postcovidr_df = covidrent_df.loc[covidrent_df['Month'].isin(['2021-03-01', '2022-06-01'])]
postcovidr_df

postcovidr_pct=postcovidr_df[['Manhattan','Brooklyn','Queens']].pct_change()
postcovidr_pct
# Out:
#      Manhattan  Brooklyn    Queens
# 170        NaN       NaN       NaN
# 185   0.347074  0.227457  0.184545

# %%
#focus on rent price during 2021-03 to 2022-06  - the sharp raise 
covidrent_df = rentprice_df.loc[(rentprice_df['Month'] >= '2021-03-01')]

# %%
saleprice_df = pd.read_csv('medianSalesPrice_All.csv') #detailed sale prices 
salevol_df = pd.read_csv('recordedSalesVolume_All.csv') #volume of house sale
saleinven_df = pd.read_csv('totalInventory_All.csv') #sell hohuse inventory
rentinven_df = pd.read_csv('rentalInventory_All.csv') #rent inventory
nprop_df = pd.read_csv('Housing_New_York_Units_by_Building.csv') #new properties
salevol_df.head(10)
# Out:
#               areaName    Borough      areaType  2010-01  2010-02  2010-03  \
# 0         All Downtown  Manhattan     submarket      291      284      347
# 1          All Midtown  Manhattan     submarket      201      166      205
# 2  All Upper East Side  Manhattan     submarket      218      241      233
# 3  All Upper Manhattan  Manhattan     submarket      122       88       84
# 4  All Upper West Side  Manhattan     submarket      211      189      244
# 5              Astoria     Queens  neighborhood       31       26       47
# 6           Auburndale     Queens  neighborhood       19       13        8
# 7           Bath Beach   Brooklyn  neighborhood       17       15       17
# 8    Battery Park City  Manhattan  neighborhood        7       10       10
# 9            Bay Ridge   Brooklyn  neighborhood       37       32       36
#
#    2010-04  2010-05  2010-06  2010-07  ...  2021-09  2021-10  2021-11  \
# 0      369      346      532      345  ...      499      564      410
# 1      208      209      295      241  ...      271      292      234
# 2      259      229      328      258  ...      344      333      244
# 3      131      100      189      110  ...      139      116      134
# 4      230      226      300      209  ...      261      233      223
# 5       49       32       47       42  ...       48       40       38
# 6       16       11       42       18  ...       22       25       19
# 7       16        9       22        9  ...       14       16       23
# 8       13       20        9        9  ...       22       21        5
# 9       36       29       78       39  ...       36       53       50
#
#    2021-12  2022-01  2022-02  2022-03  2022-04  2022-05  2022-06
# 0      516      372      407      536      434      479      241
# 1      250      230      239      307      239      291      133
# 2      278      207      261      289      254      279      174
# 3      109      104      120      160      123      124       55
# 4      220      211      213      232      220      247      133
# 5       70       58       58       59       55       59       37
# 6       27       19       20       26       18       14        7
# 7       14       14       20       18       18       13        6
# 8       28       12       20       14       13       12        8
# 9       55       36       50       49       50       46       31
#
# [10 rows x 153 columns]

# %%
salevol_dfcovid = salevol_df.loc[5:,["areaName","Borough","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03"]]
salevol_dfsum = salevol_dfcovid.groupby('Borough',as_index=False).sum()
salevolswap = salevol_dfsum.transpose()
salevolswap = salevolswap.rename(columns=salevolswap.iloc[0]).drop(salevolswap.index[0])
salevolswap
salevol_dfsum
salevolswap = salevolswap.reset_index()

salevolswap.columns
salevolswap = salevolswap.rename(columns={"index":"Month"})
salevolswap
# Out:
#       Month Bronx Brooklyn Manhattan Queens Staten Island
# 0   2020-01   791     3027      1880   3961           372
# 1   2020-02   643     2511      1898   3290           337
# 2   2020-03   543     2481      1444   2995           306
# 3   2020-04   314     1491       900   1473           183
# 4   2020-05   329     1812      1134   1795           219
# 5   2020-06   503     2121      1532   2369           294
# 6   2020-07   499     1887      1332   2601           226
# 7   2020-08   411     1701       972   2382           283
# 8   2020-09   485     2007       954   2469           384
# 9   2020-10   543     2610      1300   3373           552
# 10  2020-11   565     2751      1304   3182           505
# 11  2020-12   727     3687      1936   4304           564
# 12  2021-01   601     2985      1578   3351           493
# 13  2021-02   625     2775      1582   3145           404
# 14  2021-03   743     3639      2540   4297           495

# %%
counts_df = pd.DataFrame(df.groupby('col1').size()

# %%
nprop2022_df = nprop_df.loc[0:68,["Project Name","Project Start Date","Number","Borough","Total Units"]]
nprop2022_sum = nprop2022_df.groupby('Borough',as_index = False).sum()

# %%
#pull out data from 2022-03 to 2022-06 where the price raise sharply
sales_tf = saleprice_df.loc[5:,["areaName","Borough","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"]]
vol_df = salevol_df.loc[5:,["areaName","Borough","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"]]
inven_df = saleinven_df.loc[5:,["areaName","Borough","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"]]
rentinven_df = rentinven_df.loc[5:,["areaName","Borough","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"]]

covidr_df = rentprice_df.loc[(rentprice_df['Month'] >= '2021-12-01')]

sellprice_median = sales_tf.groupby('Borough',as_index=False).median() # median of recorded sales price 
salesvol_sum = vol_df.groupby('Borough',as_index=False).sum() # sum of recorded sales volume 
inven_sum = inven_df.groupby('Borough',as_index=False).sum() # sum of houseing inventory
rentinven_sum = rentinven_df.groupby('Borough',as_index=False).sum() #sum of rent inventory
sellprice_median

salesvol_sum
# Out:
#          Borough  2021-11  2021-12  2022-01  2022-02  2022-03  2022-04  \
# 0          Bronx      677      899      580      715      659      653
# 1       Brooklyn     3769     4137     3158     3444     3909     3366
# 2      Manhattan     2538     2756     2254     2486     3060     2566
# 3         Queens     4011     4716     3756     3945     4323     3642
# 4  Staten Island      461      501      435      394      482      404
#
#    2022-05  2022-06
# 0      756      311
# 1     3687     1734
# 2     2846     1476
# 3     4248     1884
# 4      330       55

# %%
rentinven_sum.corrwith(inven_sum, axis = 1)
#correlation between rent house incentory and sell house inventory
# Out:
# 0    0.393643
# 1    0.613916
# 2    0.901785
# 3   -0.528437
# 4    0.577004
# dtype: float64

# %%
sellprice_median
sellprice_median.corrwith(salesvol_sum, axis = 1)
#correlation between sell price and sell house volume
# Out:
# 0    0.753228
# 1   -0.020426
# 2   -0.849007
# 3    0.898657
# 4   -0.833744
# dtype: float64

# %%
salesvol_sum
# Out:
#          Borough  2021-11  2021-12  2022-01  2022-02  2022-03  2022-04  \
# 0          Bronx      677      899      580      715      659      653
# 1       Brooklyn     3769     4137     3158     3444     3909     3366
# 2      Manhattan     2538     2756     2254     2486     3060     2566
# 3         Queens     4011     4716     3756     3945     4323     3642
# 4  Staten Island      461      501      435      394      482      404
#
#    2022-05  2022-06
# 0      756      311
# 1     3687     1734
# 2     2846     1476
# 3     4248     1884
# 4      330       55

# %%
sellprice_median.plot(x='Borough', y=["2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"], kind="bar", figsize=(15,6),title='Median of sales prices')
plt.xticks(rotation='horizontal')
salesvol_sum.plot(x='Borough', y=["2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"], kind="bar", figsize=(15,6),title='Sum of recorded sales volume')
plt.xticks(rotation='horizontal')
inven_sum.plot(x='Borough', y=["2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"], kind="bar", figsize=(15,6),title='Sum of house inventory')
plt.xticks(rotation='horizontal')
rentinven_sum.plot(x='Borough', y=["2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"], kind="bar", figsize=(15,6),title='Sum of rental inventory')
plt.xticks(rotation='horizontal')
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Bronx'),
#   Text(1, 0, 'Brooklyn'),
#   Text(2, 0, 'Manhattan'),
#   Text(3, 0, 'Queens'),
#   Text(4, 0, 'Staten Island')])

# %%
mortage_rate = pd.read_csv('MORTGAGE30US.csv') #Fixed Rate Mortgage Average 
mortage_rate
mortage_rate = mortage_rate.loc[(mortage_rate['DATE'] >= '2021-03-01')]

plt.rcParams['figure.figsize']=(10,6)
mortage_rate.plot(x='DATE',y=['MORTGAGE30US'])
plt.xlabel('Month') 
#plt.xticks(rotation='vertical')
plt.ylabel('Mortage Rate')
plt.title('Fixed Rate Mortgage Average', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Fixed Rate Mortgage Average')

# %%
mortage_rate22 = mortage_rate.loc[(mortage_rate['DATE'] >= '2021-10-15')]

plt.rcParams['figure.figsize']=(10,6)
mortage_rate22.plot(x='DATE',y=['MORTGAGE30US'])
plt.xlabel('Month') 
#plt.xticks(rotation='vertical')
plt.ylabel('Mortage Rate')
plt.title('Fixed Rate Mortgage Average', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Fixed Rate Mortgage Average')

# %%
rentinven_df['April to June'] = rentinven_df['2022-06'] - rentinven_df['2022-04']
rentinven_df.nsmallest(20, 'April to June')
# Out:
#              areaName    Borough  2021-11  2021-12  2022-01  2022-02  2022-03  \
# 150            Queens     Queens     4958     4293     4267     4121     4475
# 165    South Brooklyn   Brooklyn     2926     2576     2644     2695     2908
# 35     Central Queens     Queens     1546     1254     1253     1209     1420
# 9           Bay Ridge   Brooklyn      434      389      360      329      369
# 5             Astoria     Queens     1652     1399     1279     1192     1167
# 131  Northeast Queens     Queens      586      561      642      707      783
# 153         Rego Park     Queens      239      207      162      162      221
# 133  Northwest Queens     Queens     2507     2195     2054     1890     1918
# 98        Kew Gardens     Queens      135      153      154      173      159
# 28           Bushwick   Brooklyn     1425     1303     1244     1153     1524
# 86   Hamilton Heights  Manhattan      397      347      318      288      317
# 168      South Queens     Queens      259      210      243      249      288
# 196          Woodside     Queens       97       87       84       66       93
# 174         Sunnyside     Queens      197      187      173      170      178
# 48             Corona     Queens       40       24       50       62       66
# 30           Canarsie   Brooklyn       37       35       40       41       58
# 74       Forest Hills     Queens      392      338      304      315      364
# 82          Gravesend   Brooklyn       88       94       95      102      119
# 93    Jackson Heights     Queens      124       94      116      110      130
# 21     Brighton Beach   Brooklyn       59       63       71       71       97
#
#      2022-04  2022-05  2022-06  April to June
# 150     3923     3790     3672           -251
# 165     2493     2622     2364           -129
# 35      1212     1170     1109           -103
# 9        327      243      238            -89
# 5       1006      894      940            -66
# 131      667      662      602            -65
# 153      196      165      145            -51
# 133     1694     1614     1645            -49
# 98       141      110      101            -40
# 28      1357     1205     1327            -30
# 86       256      245      226            -30
# 168      288      288      259            -29
# 196       68       62       42            -26
# 174      131      119      107            -24
# 48        47       36       25            -22
# 30        52       52       31            -21
# 74       316      286      295            -21
# 82        99       96       80            -19
# 93       125      116      106            -19
# 21        74       85       56            -18

# %%
inven_larg = rentinven_df.nlargest(20, 'April to June')
inven_larg
# Out:
#                areaName    Borough  2021-11  2021-12  2022-01  2022-02  \
# 126                 NYC        NaN    28255    25031    25320    24346
# 108           Manhattan  Manhattan    11787    10438    10740    10548
# 24             Brooklyn   Brooklyn    10531     9438     9432     8727
# 181     Upper East Side  Manhattan     1806     1450     1445     1352
# 129      North Brooklyn   Brooklyn     1101     1041     1132     1011
# 63         East Village  Manhattan      581      583      667      604
# 182     Upper West Side  Manhattan     1353     1245     1315     1313
# 57        East Brooklyn   Brooklyn     4430     3972     3761     3145
# 192        Williamsburg   Brooklyn      889      856      920      807
# 132  Northwest Brooklyn   Brooklyn     1143     1045     1090     1144
# 13   Bedford-Stuyvesant   Brooklyn     1652     1391     1322     1044
# 116        Midtown East  Manhattan     1253     1157     1199     1234
# 51        Crown Heights   Brooklyn     1138     1095      971      779
# 36              Chelsea  Manhattan      412      347      429      459
# 148       Prospect Park   Brooklyn      930      804      803      728
# 107     Lower East Side  Manhattan      425      336      355      380
# 67   Financial District  Manhattan      477      432      472      442
# 83           Greenpoint   Brooklyn      212      185      212      204
# 84    Greenwich Village  Manhattan      183      168      176      168
# 118        Midtown West  Manhattan      834      752      741      853
#
#      2022-03  2022-04  2022-05  2022-06  April to June
# 126    27680    26215    28788    30262           4047
# 108    12079    12326    14183    15336           3010
# 24     10020     9060     9751    10217           1157
# 181     1562     1689     1959     2337            648
# 129     1263     1090     1275     1566            476
# 63       707      800     1067     1225            425
# 182     1517     1585     1789     1985            400
# 57      3869     3497     3642     3891            394
# 192      994      868     1012     1212            344
# 132     1217     1243     1400     1503            260
# 13      1265     1157     1277     1394            237
# 116     1397     1361     1508     1559            198
# 51       886      774      912      959            185
# 36       557      563      674      725            162
# 148      759      735      810      889            154
# 107      463      496      592      647            151
# 67       502      435      528      573            138
# 83       269      222      263      354            132
# 84       180      215      309      331            116
# 118      985      930     1020     1045            115

# %%
nprop2022_sum #new properties from 2022-01 to 2022-03
# Out:
#          Borough  Total Units
# 0          Bronx          686
# 1       Brooklyn          971
# 2      Manhattan          467
# 3         Queens           94
# 4  Staten Island            5

# %%
inflation_df = pd.read_csv('mcpi_revised.csv')
inflation_df = inflation_df.loc[455:,["date ","mcpi_ann_monthly_chg"]]
inflation_df

plt.rcParams['figure.figsize']=(12,6)
inflation_df.plot(x='date ',y=["mcpi_ann_monthly_chg"])
plt.xlabel('Month') 
#plt.xticks(rotation='vertical')
plt.ylabel('CPI')
plt.title('Median CPI', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Median CPI')
